# %%
import os
if not os.path.exists("../docs/"):
    os.makedirs("../docs/")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from typing import List, Union, Any, Optional
from selenium.webdriver.support import expected_conditions as EC
import time
from bs4 import BeautifulSoup

# %%
import logging

logging.basicConfig(
    filename='../logs/scrape_austlii.log',
    filemode='w',
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    level=logging.INFO
)

# %%
import os
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_experimental_option('prefs', {
    # Change default directory for downloads
    "download.default_directory": "/Users/home/projects/selenium/docs/TO_BE_CLEANED/",
    "download.prompt_for_download": False,  # To auto download the file
    "download.directory_upgrade": True,
    # It will not show PDF directly in chrome
    "plugins.always_open_pdf_externally": True
})

if not os.path.exists("../docs/TO_BE_CLEANED/"):
    os.makedirs("../docs/TO_BE_CLEANED/")

# %% [markdown]
# ## Scrape 1 austlii url

# %%
def get_url_content(path: Optional[str] = None, url: Optional[str] = None, driver: Optional[webdriver.Chrome] = None) -> str:
    if driver is None and url is None:
        raise ValueError("Either url or driver must be provided")
    if driver is None:
        driver = webdriver.Chrome(options=chrome_options)
    if url is not None:
        driver.get(url)
    if path is not None:
        if not os.path.exists(path):
            os.makedirs(path)
        if not path.endswith('/'):
            path += '/'

    article = driver.find_elements(By.TAG_NAME, 'article')
    article = article[0].text

    # Extract the title from the first line of the article text
    title = article.split('\n')[0]

    # Replace any characters in title that are not suitable for filenames
    title = "".join(c for c in title if c.isalnum()
                    or c in [' ', '.']).rstrip()

    if path is not None:
        with open(path + title + ".txt", "w") as f:
            f.write(article)
    return article

# %% [markdown]
# ### Unit test

# %%
url = "http://www.austlii.edu.au/cgi-bin/viewdoc/au/cases/act/ACTCA//2023/15.html"
article = get_url_content(url=url)
print(article)

# %% [markdown]
# ## Recursively scrape all of austlii

# %% [markdown]
# ### Funcs

# %%
def write_to_file(article: str, path: str) -> None:
    if not os.path.exists(path):
        os.makedirs(path)
    if not path.endswith('/'):
        path += '/'

    lines = article.split('\n')

    # Find the index of the first line containing alphanumeric characters
    first_alnum_line_index = next((i for i, line in enumerate(
        lines) if any(c.isalnum() for c in line)), None)

    if first_alnum_line_index is not None:
        # Extract the title from the first line of the article text
        title = lines[first_alnum_line_index]
        # Replace any characters in title that are not suitable for filenames
        title = "".join(c for c in title if c.isalnum()
                        or c in [' ', '.']).rstrip()

        content = '\n'.join(lines[first_alnum_line_index:])

        with open(f'{path}{title}.txt', 'w') as f:
            f.write(content)

# %%
def scrape_austlii(url: str, path: str) -> List[str]:
    if not os.path.exists(path):
        os.makedirs(path)
    if not path.endswith('/'):
        path += '/'

    retv = []

    try:
        driver = webdriver.Chrome(options=chrome_options)
        logging.info('Launching Chrome browser.')
    except Exception as e:
        logging.error(f'Failed to launch Chrome browser: {e}')

    try:
        driver.get(url)
        logging.info('Navigating to the URL.')
    except Exception as e:
        logging.error(f'Failed to navigate to the URL: {e}')

    try:
        # Find all <a> tags linking to a document on the current page
        els = WebDriverWait(driver, timeout=3).until(
            EC.presence_of_all_elements_located(
                (By.XPATH, '//div[@class="card"]/ul/li/a'))
        )
        # Extract the href attribute from each <a> tag
        links = [el.get_attribute('href') for el in els]
        logging.info('Extracting the href attribute from each <a> tag.')
        logging.info(f'Found {len(links)} links.')

        # Iterate through each link and download the document
        for link in links:
            # Navigate to the document page
            driver.get(link)
            logging.info(f'Navigated to the link: {link}.')

            try:
                # Look for an <a> tag that begins with “Plain text”
                download1 = WebDriverWait(driver, timeout=3).until(
                    lambda d: d.find_element(By.XPATH, '//a[starts-with(text(), "Plain text")]'))
                download1.click()
                logging.info('Clicked on "Plain text" download link.')
            except Exception:
                try:
                    logging.info(
                        'No "RTF format" download link found. Calling get_url_content() function.')
                    text = get_url_content(driver=driver)
                    write_to_file(article=text, path=path)
                    retv.append(text)
                    logging.info('Writing the document to file.')
                    continue
                except Exception as e:
                    logging.error(
                        f'Failed to get the document content: {e}')
                    continue
            logging.info('Waiting for the document to be initialised.')
            source = driver.page_source
            text = BeautifulSoup(source, 'html.parser').text
            logging.info('Getting the page source.')
            retv.append(text)
            write_to_file(article=text, path=path)
            logging.info('Writing the document to file.')
    except Exception as e:
        logging.error(
            f'Failed during the navigation and click operations: {e}')
    return retv

# %%
from typing import List, Optional, Tuple


def get_links(XPATH: str, url: Optional[str] = None, driver: Optional[webdriver.Chrome] = None, quit: bool = True) -> List[Tuple[str, str]]:
    if not driver:
        driver = webdriver.Chrome(options=chrome_options)
    if url:
        driver.get(url)
    els = WebDriverWait(driver, timeout=3).until(
        EC.presence_of_all_elements_located(
            (By.XPATH, XPATH))
    )
    links = [el.get_attribute('href') for el in els]
    texts = [el.text for el in els]
    if quit:
        driver.quit()
    return list(zip(texts, links))

# %%
from datetime import date
from concurrent.futures import ThreadPoolExecutor


def concurrent_scrape(cth_links, base_path):
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = []
        for doc_type, urls in cth_links.items():
            # Convert the doc_type to uppercase and replace any spaces with underscores
            doc_type_formatted = doc_type.upper().replace(' ', '_')
            for url in urls:
                # Create a folder path with the current date and document type
                today_date = date.today().isoformat()
                path_specific = f'{base_path}/{today_date}__{doc_type_formatted}'
                futures.append(executor.submit(
                    scrape_austlii, url, path_specific))

        results = []
        for future in futures:
            results.append(future.result())

        return results

# %% [markdown]
# ### Scraping

# %%
driver = webdriver.Chrome(options=chrome_options)
starting_url = 'http://www8.austlii.edu.au/au/cth/'
cth_links = {}

link_mappings = {
    'cth_cases': '//*[@id="cth_cases"]//a',
    'cth_legis': '//*[@id="cth_legis"]//a',
    'cth_other': '//*[@id="cth_other"]//a',
    'cth_tax_rulings': '//*[@id="cth_tax_rulings"]//a'
}

for key, xpath in link_mappings.items():
    cth_links[key] = get_links(url=starting_url, XPATH=xpath, driver=driver)

for k, v in cth_links.items():
    print(k, len(v))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:200, in HTTPConnection._new_conn(self)
#     199 try:
# --> 200     sock = connection.create_connection(
#     201         (self._dns_host, self.port),
#     202         self.timeout,
#     203         source_address=self.source_address,
#     204         socket_options=self.socket_options,
#     205     )
#     206 except socket.gaierror as e:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:388, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     387     self.putheader(header, value)
# --> 388 self.endheaders()
#     390 # If we're given a body we start sending that in chunks.
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:236, in HTTPConnection.connect(self)
#     235 def connect(self) -> None:
# --> 236     self.sock = self._new_conn()
#     237     if self._tunnel_host:
#     238         # If we're tunneling it means we're connected to our proxy.
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:215, in HTTPConnection._new_conn(self)
#     214 except OSError as e:
# --> 215     raise NewConnectionError(
#     216         self, f"Failed to establish a new connection: {e}"
#     217     ) from e
#     219 return sock
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10a42cdd0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[11], line 13
#       5 link_mappings = {
#       6     'cth_cases': '//*[@id="cth_cases"]//a',
#       7     'cth_legis': '//*[@id="cth_legis"]//a',
#       8     'cth_other': '//*[@id="cth_other"]//a',
#       9     'cth_tax_rulings': '//*[@id="cth_tax_rulings"]//a'
#      10 }
#      12 for key, xpath in link_mappings.items():
# ---> 13     cth_links[key] = get_links(url=starting_url, XPATH=xpath, driver=driver)
#      15 for k, v in cth_links.items():
#      16     print(k, len(v))
#
# Cell In[9], line 8, in get_links(XPATH, url, driver, quit)
#       6     driver = webdriver.Chrome(options=chrome_options)
#       7 if url:
# ----> 8     driver.get(url)
#       9 els = WebDriverWait(driver, timeout=3).until(
#      10     EC.presence_of_all_elements_located(
#      11         (By.XPATH, XPATH))
#      12 )
#      13 links = [el.get_attribute('href') for el in els]
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/poolmanager.py:433, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     431     response = conn.urlopen(method, url, **kw)
#     432 else:
# --> 433     response = conn.urlopen(method, u.request_uri, **kw)
#     435 redirect_location = redirect and response.get_redirect_location()
#     436 if not redirect_location:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841 elif isinstance(new_e, (OSError, HTTPException)):
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#     849 # Keep track of the error for the retry warning.
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     513 if new_retry.is_exhausted():
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     519 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=57315): Max retries exceeded with url: /session/bf4da2bc3aba8f80fc4233933703dca8/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10a42cdd0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %% [markdown]
# ### ACT

# %%
driver = webdriver.Chrome(options=chrome_options)
starting_url = 'http://www8.austlii.edu.au/au/act/'
cth_links = {}

link_mappings = {
    'act_cases': '//*[@id="act_cases"]//a',
    'act_legis': '//*[@id="act_legis"]//a',
    'act_other': '//*[@id="act_other"]//a',
}

for key, xpath in link_mappings.items():
    cth_links[key] = get_links(url=starting_url, XPATH=xpath, driver=driver)

for k, v in cth_links.items():
    print(k, len(v))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:200, in HTTPConnection._new_conn(self)
#     199 try:
# --> 200     sock = connection.create_connection(
#     201         (self._dns_host, self.port),
#     202         self.timeout,
#     203         source_address=self.source_address,
#     204         socket_options=self.socket_options,
#     205     )
#     206 except socket.gaierror as e:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:388, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     387     self.putheader(header, value)
# --> 388 self.endheaders()
#     390 # If we're given a body we start sending that in chunks.
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:236, in HTTPConnection.connect(self)
#     235 def connect(self) -> None:
# --> 236     self.sock = self._new_conn()
#     237     if self._tunnel_host:
#     238         # If we're tunneling it means we're connected to our proxy.
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connection.py:215, in HTTPConnection._new_conn(self)
#     214 except OSError as e:
# --> 215     raise NewConnectionError(
#     216         self, f"Failed to establish a new connection: {e}"
#     217     ) from e
#     219 return sock
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x108727490>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[14], line 12
#       5 link_mappings = {
#       6     'act_cases': '//*[@id="act_cases"]//a',
#       7     'act_legis': '//*[@id="act_legis"]//a',
#       8     'act_other': '//*[@id="act_other"]//a',
#       9 }
#      11 for key, xpath in link_mappings.items():
# ---> 12     cth_links[key] = get_links(url=starting_url, XPATH=xpath, driver=driver)
#      14 for k, v in cth_links.items():
#      15     print(k, len(v))
#
# Cell In[6], line 8, in get_links(XPATH, url, driver, quit)
#       6     driver = webdriver.Chrome(options=chrome_options)
#       7 if url:
# ----> 8     driver.get(url)
#       9 els = WebDriverWait(driver, timeout=3).until(
#      10     EC.presence_of_all_elements_located(
#      11         (By.XPATH, XPATH))
#      12 )
#      13 links = [el.get_attribute('href') for el in els]
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/poolmanager.py:433, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     431     response = conn.urlopen(method, url, **kw)
#     432 else:
# --> 433     response = conn.urlopen(method, u.request_uri, **kw)
#     435 redirect_location = redirect and response.get_redirect_location()
#     436 if not redirect_location:
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841 elif isinstance(new_e, (OSError, HTTPException)):
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#     849 # Keep track of the error for the retry warning.
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     513 if new_retry.is_exhausted():
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     519 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=58718): Max retries exceeded with url: /session/adea86b85255a80bb0af897271f76280/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x108727490>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
act_cases = get_links(
    url=starting_url, XPATH='//*[@id="act_cases"]//a', driver=driver)
act_cases
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 act_cases =get_links(url=starting_url, XPATH='//*[@id="act_cases"]//a', driver=driver)
#       2 act_cases
#
# Cell In[6], line 9, in get_links(XPATH, url, driver, quit)
#       7 if url:
#       8     driver.get(url)
# ----> 9 els = WebDriverWait(driver, timeout=3).until(
#      10     EC.presence_of_all_elements_located(
#      11         (By.XPATH, XPATH))
#      12 )
#      13 links = [el.get_attribute('href') for el in els]
#      14 texts = [el.text for el in els]
#
# File ~/.virtualenvs/selenium/lib/python3.11/site-packages/selenium/webdriver/support/wait.py:95, in WebDriverWait.until(self, method, message)
#      93     if time.monotonic() > end_time:
#      94         break
# ---> 95 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:

# %% [markdown]
# ## Data cleaning

# %%
import os
import subprocess

input_directory = "../docs/TO_BE_CLEANED/"
output_directory = "../docs/TO_BE_CLEANED_TXT/"

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Iterate over files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".rtf"):
        input_path = os.path.join(input_directory, filename)
        output_path = os.path.join(
            output_directory, os.path.splitext(filename)[0] + ".txt")

        # Use subprocess to run the "textutil" command-line tool to convert the file
        subprocess.run(["textutil", "-convert", "txt",
                       input_path, "-output", output_path])

        print(f"Converted {filename} to {output_path}")
# Out:
# Converted 1866.rtf to ../docs/TO_BE_CLEANED_TXT/1866.txt
# Converted 458.rtf to ../docs/TO_BE_CLEANED_TXT/458.txt
# Converted 1 (33).rtf to ../docs/TO_BE_CLEANED_TXT/1 (33).txt
# Converted 470.rtf to ../docs/TO_BE_CLEANED_TXT/470.txt
# Converted 2 (6).rtf to ../docs/TO_BE_CLEANED_TXT/2 (6).txt
# Converted 4 (11).rtf to ../docs/TO_BE_CLEANED_TXT/4 (11).txt
# Converted 5 (2).rtf to ../docs/TO_BE_CLEANED_TXT/5 (2).txt
# Converted 74 (2).rtf to ../docs/TO_BE_CLEANED_TXT/74 (2).txt
# Converted 64 (2).rtf to ../docs/TO_BE_CLEANED_TXT/64 (2).txt
# Converted 15 (4).rtf to ../docs/TO_BE_CLEANED_TXT/15 (4).txt
# Converted 15.rtf to ../docs/TO_BE_CLEANED_TXT/15.txt
# Converted 38 (3).rtf to ../docs/TO_BE_CLEANED_TXT/38 (3).txt
# Converted 28 (3).rtf to ../docs/TO_BE_CLEANED_TXT/28 (3).txt
# Converted 29.rtf to ../docs/TO_BE_CLEANED_TXT/29.txt
# Converted 85 (1).rtf to ../docs/TO_BE_CLEANED_TXT/85 (1).txt
# Converted 6 (4).rtf to ../docs/TO_BE_CLEANED_TXT/6 (4).txt
# Converted 16 (2).rtf to ../docs/TO_BE_CLEANED_TXT/16 (2).txt
# Converted 1 (25).rtf to ../docs/TO_BE_CLEANED_TXT/1 (25).txt
# Converted 262.rtf to ../docs/TO_BE_CLEANED_TXT/262.txt
# Converted 17 (3).rtf to ../docs/TO_BE_CLEANED_TXT/17 (3).txt
# Converted 288.rtf to ../docs/TO_BE_CLEANED_TXT/288.txt
# Converted 71 (1).rtf to ../docs/TO_BE_CLEANED_TXT/71 (1).txt
# Converted 61 (1).rtf to ../docs/TO_BE_CLEANED_TXT/61 (1).txt
# Converted 3 (16).rtf to ../docs/TO_BE_CLEANED_TXT/3 (16).txt
# Converted 13 (1).rtf to ../docs/TO_BE_CLEANED_TXT/13 (1).txt
# Converted 2 (16).rtf to ../docs/TO_BE_CLEANED_TXT/2 (16).txt
# Converted 28.rtf to ../docs/TO_BE_CLEANED_TXT/28.txt
# Converted 14.rtf to ../docs/TO_BE_CLEANED_TXT/14.txt
# Converted 3 (7).rtf to ../docs/TO_BE_CLEANED_TXT/3 (7).txt
# Converted 115.rtf to ../docs/TO_BE_CLEANED_TXT/115.txt
# Converted 80 (2).rtf to ../docs/TO_BE_CLEANED_TXT/80 (2).txt
# Converted 58 (4).rtf to ../docs/TO_BE_CLEANED_TXT/58 (4).txt
# Converted 14 (5).rtf to ../docs/TO_BE_CLEANED_TXT/14 (5).txt
# Converted 471.rtf to ../docs/TO_BE_CLEANED_TXT/471.txt
# Converted 65 (3).rtf to ../docs/TO_BE_CLEANED_TXT/65 (3).txt
# Converted 4 (3).rtf to ../docs/TO_BE_CLEANED_TXT/4 (3).txt
# Converted 329.rtf to ../docs/TO_BE_CLEANED_TXT/329.txt
# Converted 208 (1).rtf to ../docs/TO_BE_CLEANED_TXT/208 (1).txt
# Converted 473.rtf to ../docs/TO_BE_CLEANED_TXT/473.txt
# Converted 315.rtf to ../docs/TO_BE_CLEANED_TXT/315.txt
# Converted 671.rtf to ../docs/TO_BE_CLEANED_TXT/671.txt
# Converted 35 (1).rtf to ../docs/TO_BE_CLEANED_TXT/35 (1).txt
# Converted 842.rtf to ../docs/TO_BE_CLEANED_TXT/842.txt
# Converted 25 (1).rtf to ../docs/TO_BE_CLEANED_TXT/25 (1).txt
# Converted 16.rtf to ../docs/TO_BE_CLEANED_TXT/16.txt
# Converted 6 (8).rtf to ../docs/TO_BE_CLEANED_TXT/6 (8).txt
# Converted 57 (1).rtf to ../docs/TO_BE_CLEANED_TXT/57 (1).txt
# Converted 47 (1).rtf to ../docs/TO_BE_CLEANED_TXT/47 (1).txt
# Converted 249.rtf to ../docs/TO_BE_CLEANED_TXT/249.txt
# Converted 261.rtf to ../docs/TO_BE_CLEANED_TXT/261.txt
# Converted 21 (3).rtf to ../docs/TO_BE_CLEANED_TXT/21 (3).txt
# Converted 1 (29).rtf to ../docs/TO_BE_CLEANED_TXT/1 (29).txt
# Converted 2 (20).rtf to ../docs/TO_BE_CLEANED_TXT/2 (20).txt
# Converted 3 (20).rtf to ../docs/TO_BE_CLEANED_TXT/3 (20).txt
# Converted 248.rtf to ../docs/TO_BE_CLEANED_TXT/248.txt
# Converted 20 (2).rtf to ../docs/TO_BE_CLEANED_TXT/20 (2).txt
# Converted 857.rtf to ../docs/TO_BE_CLEANED_TXT/857.txt
# Converted 17.rtf to ../docs/TO_BE_CLEANED_TXT/17.txt
# Converted 52 (2).rtf to ../docs/TO_BE_CLEANED_TXT/52 (2).txt
# Converted 42 (2).rtf to ../docs/TO_BE_CLEANED_TXT/42 (2).txt
# Converted 23 (4).rtf to ../docs/TO_BE_CLEANED_TXT/23 (4).txt
# Converted 1 (13).rtf to ../docs/TO_BE_CLEANED_TXT/1 (13).txt
# Converted 472.rtf to ../docs/TO_BE_CLEANED_TXT/472.txt
# Converted 314.rtf to ../docs/TO_BE_CLEANED_TXT/314.txt
# Converted 300.rtf to ../docs/TO_BE_CLEANED_TXT/300.txt
# Converted 68 (1).rtf to ../docs/TO_BE_CLEANED_TXT/68 (1).txt
# Converted 328.rtf to ../docs/TO_BE_CLEANED_TXT/328.txt
# Converted 9 (1).rtf to ../docs/TO_BE_CLEANED_TXT/9 (1).txt
# Converted 310.rtf to ../docs/TO_BE_CLEANED_TXT/310.txt
# Converted 476.rtf to ../docs/TO_BE_CLEANED_TXT/476.txt
# Converted 24 (1).rtf to ../docs/TO_BE_CLEANED_TXT/24 (1).txt
# Converted 34 (1).rtf to ../docs/TO_BE_CLEANED_TXT/34 (1).txt
# Converted 489.rtf to ../docs/TO_BE_CLEANED_TXT/489.txt
# Converted 209 (1).rtf to ../docs/TO_BE_CLEANED_TXT/209 (1).txt
# Converted 1 (12).rtf to ../docs/TO_BE_CLEANED_TXT/1 (12).txt
# Converted 13.rtf to ../docs/TO_BE_CLEANED_TXT/13.txt
# Converted 2038.rtf to ../docs/TO_BE_CLEANED_TXT/2038.txt
# Converted 1082.rtf to ../docs/TO_BE_CLEANED_TXT/1082.txt
# Converted 46 (1).rtf to ../docs/TO_BE_CLEANED_TXT/46 (1).txt
# Converted 56 (1).rtf to ../docs/TO_BE_CLEANED_TXT/56 (1).txt
# Converted 1900.rtf to ../docs/TO_BE_CLEANED_TXT/1900.txt
# Converted 241 (2).rtf to ../docs/TO_BE_CLEANED_TXT/241 (2).txt
# Converted 21 (2).rtf to ../docs/TO_BE_CLEANED_TXT/21 (2).txt
# Converted 1 (28).rtf to ../docs/TO_BE_CLEANED_TXT/1 (28).txt
# Converted 2 (21).rtf to ../docs/TO_BE_CLEANED_TXT/2 (21).txt
# Converted 6 (9).rtf to ../docs/TO_BE_CLEANED_TXT/6 (9).txt
# Converted 852.rtf to ../docs/TO_BE_CLEANED_TXT/852.txt
# Converted 12.rtf to ../docs/TO_BE_CLEANED_TXT/12.txt
# Converted 2171.rtf to ../docs/TO_BE_CLEANED_TXT/2171.txt
# Converted 846.rtf to ../docs/TO_BE_CLEANED_TXT/846.txt
# Converted 79 (1).rtf to ../docs/TO_BE_CLEANED_TXT/79 (1).txt
# Converted 8 (1).rtf to ../docs/TO_BE_CLEANED_TXT/8 (1).txt
# Converted 69 (1).rtf to ../docs/TO_BE_CLEANED_TXT/69 (1).txt
# Converted 22 (4).rtf to ../docs/TO_BE_CLEANED_TXT/22 (4).txt
# Converted 311.rtf to ../docs/TO_BE_CLEANED_TXT/311.txt
# Converted 477.rtf to ../docs/TO_BE_CLEANED_TXT/477.txt
# Converted 463.rtf to ../docs/TO_BE_CLEANED_TXT/463.txt
# Converted 305.rtf to ../docs/TO_BE_CLEANED_TXT/305.txt
# Converted 14 (4).rtf to ../docs/TO_BE_CLEANED_TXT/14 (4).txt
# Converted 475.rtf to ../docs/TO_BE_CLEANED_TXT/475.txt
# Converted 307.rtf to ../docs/TO_BE_CLEANED_TXT/307.txt
# Converted 65 (2).rtf to ../docs/TO_BE_CLEANED_TXT/65 (2).txt
# Converted 75 (2).rtf to ../docs/TO_BE_CLEANED_TXT/75 (2).txt
# Converted 4 (2).rtf to ../docs/TO_BE_CLEANED_TXT/4 (2).txt
# Converted nfpia1998413.rtf to ../docs/TO_BE_CLEANED_TXT/nfpia1998413.txt
# Converted 3 (17).rtf to ../docs/TO_BE_CLEANED_TXT/3 (17).txt
# Converted 2 (17).rtf to ../docs/TO_BE_CLEANED_TXT/2 (17).txt
# Converted 38.rtf to ../docs/TO_BE_CLEANED_TXT/38.txt
# Converted 10.rtf to ../docs/TO_BE_CLEANED_TXT/10.txt
# Converted 850.rtf to ../docs/TO_BE_CLEANED_TXT/850.txt
# Converted 3 (6).rtf to ../docs/TO_BE_CLEANED_TXT/3 (6).txt
# Converted 1254.rtf to ../docs/TO_BE_CLEANED_TXT/1254.txt
# Converted 273.rtf to ../docs/TO_BE_CLEANED_TXT/273.txt
# Converted 84 (1).rtf to ../docs/TO_BE_CLEANED_TXT/84 (1).txt
# Converted 17 (2).rtf to ../docs/TO_BE_CLEANED_TXT/17 (2).txt
# Converted 298.rtf to ../docs/TO_BE_CLEANED_TXT/298.txt
# Converted 299.rtf to ../docs/TO_BE_CLEANED_TXT/299.txt
# Converted 1161 (1).rtf to ../docs/TO_BE_CLEANED_TXT/1161 (1).txt
# Converted 1 (24).rtf to ../docs/TO_BE_CLEANED_TXT/1 (24).txt
# Converted 60 (1).rtf to ../docs/TO_BE_CLEANED_TXT/60 (1).txt
# Converted 70 (1).rtf to ../docs/TO_BE_CLEANED_TXT/70 (1).txt
# Converted 1 (1).rtf to ../docs/TO_BE_CLEANED_TXT/1 (1).txt
# Converted 6 (5).rtf to ../docs/TO_BE_CLEANED_TXT/6 (5).txt
# Converted 16 (3).rtf to ../docs/TO_BE_CLEANED_TXT/16 (3).txt
# Converted 38 (2).rtf to ../docs/TO_BE_CLEANED_TXT/38 (2).txt
# Converted 28 (2).rtf to ../docs/TO_BE_CLEANED_TXT/28 (2).txt
# Converted 11.rtf to ../docs/TO_BE_CLEANED_TXT/11.txt
# Converted 39.rtf to ../docs/TO_BE_CLEANED_TXT/39.txt
# Converted 5 (3).rtf to ../docs/TO_BE_CLEANED_TXT/5 (3).txt
# Converted 64 (3).rtf to ../docs/TO_BE_CLEANED_TXT/64 (3).txt
# Converted 15 (5).rtf to ../docs/TO_BE_CLEANED_TXT/15 (5).txt
# Converted 5 (10).rtf to ../docs/TO_BE_CLEANED_TXT/5 (10).txt
# Converted 2 (7).rtf to ../docs/TO_BE_CLEANED_TXT/2 (7).txt
# Converted 296 (1).rtf to ../docs/TO_BE_CLEANED_TXT/296 (1).txt
# Converted 4 (10).rtf to ../docs/TO_BE_CLEANED_TXT/4 (10).txt
# Converted 12 (1).rtf to ../docs/TO_BE_CLEANED_TXT/12 (1).txt
# Converted 81 (2).rtf to ../docs/TO_BE_CLEANED_TXT/81 (2).txt
# Converted 1 (32).rtf to ../docs/TO_BE_CLEANED_TXT/1 (32).txt
# Converted 474.rtf to ../docs/TO_BE_CLEANED_TXT/474.txt
# Converted 215 (2).rtf to ../docs/TO_BE_CLEANED_TXT/215 (2).txt
# Converted 312.rtf to ../docs/TO_BE_CLEANED_TXT/312.txt
# Converted 22 (3).rtf to ../docs/TO_BE_CLEANED_TXT/22 (3).txt
# Converted 311 (1).rtf to ../docs/TO_BE_CLEANED_TXT/311 (1).txt
# Converted 361.rtf to ../docs/TO_BE_CLEANED_TXT/361.txt
# Converted 639.rtf to ../docs/TO_BE_CLEANED_TXT/639.txt
# Converted 188.rtf to ../docs/TO_BE_CLEANED_TXT/188.txt
# Converted 76.rtf to ../docs/TO_BE_CLEANED_TXT/76.txt
# Converted 5 (8).rtf to ../docs/TO_BE_CLEANED_TXT/5 (8).txt
# Converted 62.rtf to ../docs/TO_BE_CLEANED_TXT/62.txt
# Converted 822.rtf to ../docs/TO_BE_CLEANED_TXT/822.txt
# Converted 54 (1).rtf to ../docs/TO_BE_CLEANED_TXT/54 (1).txt
# Converted 36 (1).rtf to ../docs/TO_BE_CLEANED_TXT/36 (1).txt
# Converted 26 (1).rtf to ../docs/TO_BE_CLEANED_TXT/26 (1).txt
# Converted 771.rtf to ../docs/TO_BE_CLEANED_TXT/771.txt
# Converted 2049.rtf to ../docs/TO_BE_CLEANED_TXT/2049.txt
# Converted 229.rtf to ../docs/TO_BE_CLEANED_TXT/229.txt
# Converted 215.rtf to ../docs/TO_BE_CLEANED_TXT/215.txt
# Converted 2 (26).rtf to ../docs/TO_BE_CLEANED_TXT/2 (26).txt
# Converted 214.rtf to ../docs/TO_BE_CLEANED_TXT/214.txt
# Converted 200.rtf to ../docs/TO_BE_CLEANED_TXT/200.txt
# Converted 1227.rtf to ../docs/TO_BE_CLEANED_TXT/1227.txt
# Converted 51 (2).rtf to ../docs/TO_BE_CLEANED_TXT/51 (2).txt
# Converted 2128.rtf to ../docs/TO_BE_CLEANED_TXT/2128.txt
# Converted 234 (1).rtf to ../docs/TO_BE_CLEANED_TXT/234 (1).txt
# Converted 63.rtf to ../docs/TO_BE_CLEANED_TXT/63.txt
# Converted 189.rtf to ../docs/TO_BE_CLEANED_TXT/189.txt
# Converted 77.rtf to ../docs/TO_BE_CLEANED_TXT/77.txt
# Converted 162.rtf to ../docs/TO_BE_CLEANED_TXT/162.txt
# Converted 88.rtf to ../docs/TO_BE_CLEANED_TXT/88.txt
# Converted 1 (15).rtf to ../docs/TO_BE_CLEANED_TXT/1 (15).txt
# Converted 23 (2).rtf to ../docs/TO_BE_CLEANED_TXT/23 (2).txt
# Converted 13364.rtf to ../docs/TO_BE_CLEANED_TXT/13364.txt
# Converted 4 (9).rtf to ../docs/TO_BE_CLEANED_TXT/4 (9).txt
# Converted 19 (1).rtf to ../docs/TO_BE_CLEANED_TXT/19 (1).txt
# Converted 1 (35).rtf to ../docs/TO_BE_CLEANED_TXT/1 (35).txt
# Converted 13399.rtf to ../docs/TO_BE_CLEANED_TXT/13399.txt
# Converted 404.rtf to ../docs/TO_BE_CLEANED_TXT/404.txt
# Converted 362.rtf to ../docs/TO_BE_CLEANED_TXT/362.txt
# Converted 376.rtf to ../docs/TO_BE_CLEANED_TXT/376.txt
# Converted 1153.rtf to ../docs/TO_BE_CLEANED_TXT/1153.txt
# Converted 12 (6).rtf to ../docs/TO_BE_CLEANED_TXT/12 (6).txt
# Converted 1147.rtf to ../docs/TO_BE_CLEANED_TXT/1147.txt
# Converted 64 (4).rtf to ../docs/TO_BE_CLEANED_TXT/64 (4).txt
# Converted 5 (4).rtf to ../docs/TO_BE_CLEANED_TXT/5 (4).txt
# Converted 160.rtf to ../docs/TO_BE_CLEANED_TXT/160.txt
# Converted 1392.rtf to ../docs/TO_BE_CLEANED_TXT/1392.txt
# Converted 15 (2).rtf to ../docs/TO_BE_CLEANED_TXT/15 (2).txt
# Converted 61.rtf to ../docs/TO_BE_CLEANED_TXT/61.txt
# Converted 75.rtf to ../docs/TO_BE_CLEANED_TXT/75.txt
# Converted 59 (3).rtf to ../docs/TO_BE_CLEANED_TXT/59 (3).txt
# Converted 49.rtf to ../docs/TO_BE_CLEANED_TXT/49.txt
# Converted 6 (2).rtf to ../docs/TO_BE_CLEANED_TXT/6 (2).txt
# Converted 77 (2).rtf to ../docs/TO_BE_CLEANED_TXT/77 (2).txt
# Converted 799.rtf to ../docs/TO_BE_CLEANED_TXT/799.txt
# Converted 67 (2).rtf to ../docs/TO_BE_CLEANED_TXT/67 (2).txt
# Converted 16 (4).rtf to ../docs/TO_BE_CLEANED_TXT/16 (4).txt
# Converted 1 (6).rtf to ../docs/TO_BE_CLEANED_TXT/1 (6).txt
# Converted 1 (23).rtf to ../docs/TO_BE_CLEANED_TXT/1 (23).txt
# Converted 216.rtf to ../docs/TO_BE_CLEANED_TXT/216.txt
# Converted 202.rtf to ../docs/TO_BE_CLEANED_TXT/202.txt
# Converted 1999.rtf to ../docs/TO_BE_CLEANED_TXT/1999.txt
# Converted 66 (3).rtf to ../docs/TO_BE_CLEANED_TXT/66 (3).txt
# Converted 203.rtf to ../docs/TO_BE_CLEANED_TXT/203.txt
# Converted 217.rtf to ../docs/TO_BE_CLEANED_TXT/217.txt
# Converted 83 (2).rtf to ../docs/TO_BE_CLEANED_TXT/83 (2).txt
# Converted 10 (1).rtf to ../docs/TO_BE_CLEANED_TXT/10 (1).txt
# Converted 2 (10).rtf to ../docs/TO_BE_CLEANED_TXT/2 (10).txt
# Converted 48.rtf to ../docs/TO_BE_CLEANED_TXT/48.txt
# Converted 3 (10).rtf to ../docs/TO_BE_CLEANED_TXT/3 (10).txt
# Converted 74.rtf to ../docs/TO_BE_CLEANED_TXT/74.txt
# Converted 3 (1).rtf to ../docs/TO_BE_CLEANED_TXT/3 (1).txt
# Converted 72 (1).rtf to ../docs/TO_BE_CLEANED_TXT/72 (1).txt
# Converted 1 (19).rtf to ../docs/TO_BE_CLEANED_TXT/1 (19).txt
# Converted 62 (1).rtf to ../docs/TO_BE_CLEANED_TXT/62 (1).txt
# Converted 820.rtf to ../docs/TO_BE_CLEANED_TXT/820.txt
# Converted 60.rtf to ../docs/TO_BE_CLEANED_TXT/60.txt
# Converted 161.rtf to ../docs/TO_BE_CLEANED_TXT/161.txt
# Converted 1393.rtf to ../docs/TO_BE_CLEANED_TXT/1393.txt
# Converted 1146.rtf to ../docs/TO_BE_CLEANED_TXT/1146.txt
# Converted 1152.rtf to ../docs/TO_BE_CLEANED_TXT/1152.txt
# Converted 58 (2).rtf to ../docs/TO_BE_CLEANED_TXT/58 (2).txt
# Converted 388.rtf to ../docs/TO_BE_CLEANED_TXT/388.txt
# Converted 14 (3).rtf to ../docs/TO_BE_CLEANED_TXT/14 (3).txt
# Converted 13398.rtf to ../docs/TO_BE_CLEANED_TXT/13398.txt
# Converted 4 (5).rtf to ../docs/TO_BE_CLEANED_TXT/4 (5).txt
# Converted 401.rtf to ../docs/TO_BE_CLEANED_TXT/401.txt
# Converted 14 (2).rtf to ../docs/TO_BE_CLEANED_TXT/14 (2).txt
# Converted 13388.rtf to ../docs/TO_BE_CLEANED_TXT/13388.txt
# Converted 4 (4).rtf to ../docs/TO_BE_CLEANED_TXT/4 (4).txt
# Converted 1156.rtf to ../docs/TO_BE_CLEANED_TXT/1156.txt
# Converted 58 (3).rtf to ../docs/TO_BE_CLEANED_TXT/58 (3).txt
# Converted 398.rtf to ../docs/TO_BE_CLEANED_TXT/398.txt
# Converted 1397.rtf to ../docs/TO_BE_CLEANED_TXT/1397.txt
# Converted 165.rtf to ../docs/TO_BE_CLEANED_TXT/165.txt
# Converted 1383.rtf to ../docs/TO_BE_CLEANED_TXT/1383.txt
# Converted 159.rtf to ../docs/TO_BE_CLEANED_TXT/159.txt
# Converted 2 (11).rtf to ../docs/TO_BE_CLEANED_TXT/2 (11).txt
# Converted 58.rtf to ../docs/TO_BE_CLEANED_TXT/58.txt
# Converted 818.rtf to ../docs/TO_BE_CLEANED_TXT/818.txt
# Converted 3 (11).rtf to ../docs/TO_BE_CLEANED_TXT/3 (11).txt
# Converted 64.rtf to ../docs/TO_BE_CLEANED_TXT/64.txt
# Converted 1 (18).rtf to ../docs/TO_BE_CLEANED_TXT/1 (18).txt
# Converted 70.rtf to ../docs/TO_BE_CLEANED_TXT/70.txt
# Converted 830.rtf to ../docs/TO_BE_CLEANED_TXT/830.txt
# Converted 213.rtf to ../docs/TO_BE_CLEANED_TXT/213.txt
# Converted 207.rtf to ../docs/TO_BE_CLEANED_TXT/207.txt
# Converted 309 (1).rtf to ../docs/TO_BE_CLEANED_TXT/309 (1).txt
# Converted 17 (4).rtf to ../docs/TO_BE_CLEANED_TXT/17 (4).txt
# Converted 66 (2).rtf to ../docs/TO_BE_CLEANED_TXT/66 (2).txt
# Converted 7 (2).rtf to ../docs/TO_BE_CLEANED_TXT/7 (2).txt
# Converted 82 (2).rtf to ../docs/TO_BE_CLEANED_TXT/82 (2).txt
# Converted 216 (2).rtf to ../docs/TO_BE_CLEANED_TXT/216 (2).txt
# Converted 1 (7).rtf to ../docs/TO_BE_CLEANED_TXT/1 (7).txt
# Converted 1 (22).rtf to ../docs/TO_BE_CLEANED_TXT/1 (22).txt
# Converted 11 (1).rtf to ../docs/TO_BE_CLEANED_TXT/11 (1).txt
# Converted 212.rtf to ../docs/TO_BE_CLEANED_TXT/212.txt
# Converted 6 (3).rtf to ../docs/TO_BE_CLEANED_TXT/6 (3).txt
# Converted 67 (3).rtf to ../docs/TO_BE_CLEANED_TXT/67 (3).txt
# Converted 16 (5).rtf to ../docs/TO_BE_CLEANED_TXT/16 (5).txt
# Converted 776.rtf to ../docs/TO_BE_CLEANED_TXT/776.txt
# Converted 71.rtf to ../docs/TO_BE_CLEANED_TXT/71.txt
# Converted 65.rtf to ../docs/TO_BE_CLEANED_TXT/65.txt
# Converted 59 (2).rtf to ../docs/TO_BE_CLEANED_TXT/59 (2).txt
# Converted 59.rtf to ../docs/TO_BE_CLEANED_TXT/59.txt
# Converted 5 (5).rtf to ../docs/TO_BE_CLEANED_TXT/5 (5).txt
# Converted 158.rtf to ../docs/TO_BE_CLEANED_TXT/158.txt
# Converted 326 (1).rtf to ../docs/TO_BE_CLEANED_TXT/326 (1).txt
# Converted 15 (3).rtf to ../docs/TO_BE_CLEANED_TXT/15 (3).txt
# Converted 164.rtf to ../docs/TO_BE_CLEANED_TXT/164.txt
# Converted 63 (1).rtf to ../docs/TO_BE_CLEANED_TXT/63 (1).txt
# Converted 73 (1).rtf to ../docs/TO_BE_CLEANED_TXT/73 (1).txt
# Converted 2 (1).rtf to ../docs/TO_BE_CLEANED_TXT/2 (1).txt
# Converted 399.rtf to ../docs/TO_BE_CLEANED_TXT/399.txt
# Converted 12 (7).rtf to ../docs/TO_BE_CLEANED_TXT/12 (7).txt
# Converted 1157.rtf to ../docs/TO_BE_CLEANED_TXT/1157.txt
# Converted 1 (34).rtf to ../docs/TO_BE_CLEANED_TXT/1 (34).txt
# Converted 13389.rtf to ../docs/TO_BE_CLEANED_TXT/13389.txt
# Converted 400.rtf to ../docs/TO_BE_CLEANED_TXT/400.txt
# Converted 358.rtf to ../docs/TO_BE_CLEANED_TXT/358.txt
# Converted 55 (1).rtf to ../docs/TO_BE_CLEANED_TXT/55 (1).txt
# Converted 1155.rtf to ../docs/TO_BE_CLEANED_TXT/1155.txt
# Converted 4 (8).rtf to ../docs/TO_BE_CLEANED_TXT/4 (8).txt
# Converted 1169.rtf to ../docs/TO_BE_CLEANED_TXT/1169.txt
# Converted 166.rtf to ../docs/TO_BE_CLEANED_TXT/166.txt
# Converted 1394.rtf to ../docs/TO_BE_CLEANED_TXT/1394.txt
# Converted 628.rtf to ../docs/TO_BE_CLEANED_TXT/628.txt
# Converted 300 (1).rtf to ../docs/TO_BE_CLEANED_TXT/300 (1).txt
# Converted 1 (14).rtf to ../docs/TO_BE_CLEANED_TXT/1 (14).txt
# Converted 23 (3).rtf to ../docs/TO_BE_CLEANED_TXT/23 (3).txt
# Converted 9.rtf to ../docs/TO_BE_CLEANED_TXT/9.txt
# Converted 73.rtf to ../docs/TO_BE_CLEANED_TXT/73.txt
# Converted 199.rtf to ../docs/TO_BE_CLEANED_TXT/199.txt
# Converted 67.rtf to ../docs/TO_BE_CLEANED_TXT/67.txt
# Converted 774.rtf to ../docs/TO_BE_CLEANED_TXT/774.txt
# Converted 27 (1).rtf to ../docs/TO_BE_CLEANED_TXT/27 (1).txt
# Converted 37 (1).rtf to ../docs/TO_BE_CLEANED_TXT/37 (1).txt
# Converted 21 (4).rtf to ../docs/TO_BE_CLEANED_TXT/21 (4).txt
# Converted 239.rtf to ../docs/TO_BE_CLEANED_TXT/239.txt
# Converted 211.rtf to ../docs/TO_BE_CLEANED_TXT/211.txt
# Converted 257 (1).rtf to ../docs/TO_BE_CLEANED_TXT/257 (1).txt
# Converted 1236.rtf to ../docs/TO_BE_CLEANED_TXT/1236.txt
# Converted 198.rtf to ../docs/TO_BE_CLEANED_TXT/198.txt
# Converted 5 (9).rtf to ../docs/TO_BE_CLEANED_TXT/5 (9).txt
# Converted 66.rtf to ../docs/TO_BE_CLEANED_TXT/66.txt
# Converted 832.rtf to ../docs/TO_BE_CLEANED_TXT/832.txt
# Converted 72.rtf to ../docs/TO_BE_CLEANED_TXT/72.txt
# Converted 8.rtf to ../docs/TO_BE_CLEANED_TXT/8.txt
# Converted 629.rtf to ../docs/TO_BE_CLEANED_TXT/629.txt
# Converted 18 (1).rtf to ../docs/TO_BE_CLEANED_TXT/18 (1).txt
# Converted 167.rtf to ../docs/TO_BE_CLEANED_TXT/167.txt
# Converted 1168.rtf to ../docs/TO_BE_CLEANED_TXT/1168.txt
# Converted 1154.rtf to ../docs/TO_BE_CLEANED_TXT/1154.txt
# Converted 22 (2).rtf to ../docs/TO_BE_CLEANED_TXT/22 (2).txt
# Converted 19 (3).rtf to ../docs/TO_BE_CLEANED_TXT/19 (3).txt
# Converted 13387.rtf to ../docs/TO_BE_CLEANED_TXT/13387.txt
# Converted 340.rtf to ../docs/TO_BE_CLEANED_TXT/340.txt
# Converted 13393.rtf to ../docs/TO_BE_CLEANED_TXT/13393.txt
# Converted 1159.rtf to ../docs/TO_BE_CLEANED_TXT/1159.txt
# Converted 13378.rtf to ../docs/TO_BE_CLEANED_TXT/13378.txt
# Converted 24 (4).rtf to ../docs/TO_BE_CLEANED_TXT/24 (4).txt
# Converted 55 (2).rtf to ../docs/TO_BE_CLEANED_TXT/55 (2).txt
# Converted 397.rtf to ../docs/TO_BE_CLEANED_TXT/397.txt
# Converted 1398.rtf to ../docs/TO_BE_CLEANED_TXT/1398.txt
# Converted 80.rtf to ../docs/TO_BE_CLEANED_TXT/80.txt
# Converted 1 (17).rtf to ../docs/TO_BE_CLEANED_TXT/1 (17).txt
# Converted 156.rtf to ../docs/TO_BE_CLEANED_TXT/156.txt
# Converted 630.rtf to ../docs/TO_BE_CLEANED_TXT/630.txt
# Converted 624.rtf to ../docs/TO_BE_CLEANED_TXT/624.txt
# Converted 5.rtf to ../docs/TO_BE_CLEANED_TXT/5.txt
# Converted 57.rtf to ../docs/TO_BE_CLEANED_TXT/57.txt
# Converted 43.rtf to ../docs/TO_BE_CLEANED_TXT/43.txt
# Converted 1401.rtf to ../docs/TO_BE_CLEANED_TXT/1401.txt
# Converted 195.rtf to ../docs/TO_BE_CLEANED_TXT/195.txt
# Converted 1373.rtf to ../docs/TO_BE_CLEANED_TXT/1373.txt
# Converted 299 (1).rtf to ../docs/TO_BE_CLEANED_TXT/299 (1).txt
# Converted 793.rtf to ../docs/TO_BE_CLEANED_TXT/793.txt
# Converted 37 (2).rtf to ../docs/TO_BE_CLEANED_TXT/37 (2).txt
# Converted 1950.rtf to ../docs/TO_BE_CLEANED_TXT/1950.txt
# Converted 208.rtf to ../docs/TO_BE_CLEANED_TXT/208.txt
# Converted 27 (2).rtf to ../docs/TO_BE_CLEANED_TXT/27 (2).txt
# Converted 234.rtf to ../docs/TO_BE_CLEANED_TXT/234.txt
# Converted 50 (1).rtf to ../docs/TO_BE_CLEANED_TXT/50 (1).txt
# Converted 2 (24).rtf to ../docs/TO_BE_CLEANED_TXT/2 (24).txt
# Converted 40 (1).rtf to ../docs/TO_BE_CLEANED_TXT/40 (1).txt
# Converted 1 (8).rtf to ../docs/TO_BE_CLEANED_TXT/1 (8).txt
# Converted 235.rtf to ../docs/TO_BE_CLEANED_TXT/235.txt
# Converted 209.rtf to ../docs/TO_BE_CLEANED_TXT/209.txt
# Converted 26 (3).rtf to ../docs/TO_BE_CLEANED_TXT/26 (3).txt
# Converted 36 (3).rtf to ../docs/TO_BE_CLEANED_TXT/36 (3).txt
# Converted 1414.rtf to ../docs/TO_BE_CLEANED_TXT/1414.txt
# Converted 194.rtf to ../docs/TO_BE_CLEANED_TXT/194.txt
# Converted 1400.rtf to ../docs/TO_BE_CLEANED_TXT/1400.txt
# Converted 1366.rtf to ../docs/TO_BE_CLEANED_TXT/1366.txt
# Converted 42.rtf to ../docs/TO_BE_CLEANED_TXT/42.txt
# Converted 4.rtf to ../docs/TO_BE_CLEANED_TXT/4.txt
# Converted 56.rtf to ../docs/TO_BE_CLEANED_TXT/56.txt
# Converted 625.rtf to ../docs/TO_BE_CLEANED_TXT/625.txt
# Converted 18 (2).rtf to ../docs/TO_BE_CLEANED_TXT/18 (2).txt
# Converted 157.rtf to ../docs/TO_BE_CLEANED_TXT/157.txt
# Converted 631.rtf to ../docs/TO_BE_CLEANED_TXT/631.txt
# Converted 81.rtf to ../docs/TO_BE_CLEANED_TXT/81.txt
# Converted 8 (4).rtf to ../docs/TO_BE_CLEANED_TXT/8 (4).txt
# Converted 1399.rtf to ../docs/TO_BE_CLEANED_TXT/1399.txt
# Converted 1164.rtf to ../docs/TO_BE_CLEANED_TXT/1164.txt
# Converted 1158.rtf to ../docs/TO_BE_CLEANED_TXT/1158.txt
# Converted 13392.rtf to ../docs/TO_BE_CLEANED_TXT/13392.txt
# Converted 6 (10).rtf to ../docs/TO_BE_CLEANED_TXT/6 (10).txt
# Converted 32 (1).rtf to ../docs/TO_BE_CLEANED_TXT/32 (1).txt
# Converted 22 (1).rtf to ../docs/TO_BE_CLEANED_TXT/22 (1).txt
# Converted 290 (1).rtf to ../docs/TO_BE_CLEANED_TXT/290 (1).txt
# Converted 4 (7).rtf to ../docs/TO_BE_CLEANED_TXT/4 (7).txt
# Converted 280 (1).rtf to ../docs/TO_BE_CLEANED_TXT/280 (1).txt
# Converted 14 (1).rtf to ../docs/TO_BE_CLEANED_TXT/14 (1).txt
# Converted 13390.rtf to ../docs/TO_BE_CLEANED_TXT/13390.txt
# Converted 13384.rtf to ../docs/TO_BE_CLEANED_TXT/13384.txt
# Converted 380.rtf to ../docs/TO_BE_CLEANED_TXT/380.txt
# Converted 394.rtf to ../docs/TO_BE_CLEANED_TXT/394.txt
# Converted 83.rtf to ../docs/TO_BE_CLEANED_TXT/83.txt
# Converted 169.rtf to ../docs/TO_BE_CLEANED_TXT/169.txt
# Converted 627.rtf to ../docs/TO_BE_CLEANED_TXT/627.txt
# Converted 633.rtf to ../docs/TO_BE_CLEANED_TXT/633.txt
# Converted 155.rtf to ../docs/TO_BE_CLEANED_TXT/155.txt
# Converted 62 (3).rtf to ../docs/TO_BE_CLEANED_TXT/62 (3).txt
# Converted 40.rtf to ../docs/TO_BE_CLEANED_TXT/40.txt
# Converted 800.rtf to ../docs/TO_BE_CLEANED_TXT/800.txt
# Converted 54.rtf to ../docs/TO_BE_CLEANED_TXT/54.txt
# Converted 6.rtf to ../docs/TO_BE_CLEANED_TXT/6.txt
# Converted 3 (3).rtf to ../docs/TO_BE_CLEANED_TXT/3 (3).txt
# Converted 3 (12).rtf to ../docs/TO_BE_CLEANED_TXT/3 (12).txt
# Converted 68.rtf to ../docs/TO_BE_CLEANED_TXT/68.txt
# Converted 2 (12).rtf to ../docs/TO_BE_CLEANED_TXT/2 (12).txt
# Converted 1402.rtf to ../docs/TO_BE_CLEANED_TXT/1402.txt
# Converted 196.rtf to ../docs/TO_BE_CLEANED_TXT/196.txt
# Converted 10 (3).rtf to ../docs/TO_BE_CLEANED_TXT/10 (3).txt
# Converted 223.rtf to ../docs/TO_BE_CLEANED_TXT/223.txt
# Converted 76 (1).rtf to ../docs/TO_BE_CLEANED_TXT/76 (1).txt
# Converted 7 (1).rtf to ../docs/TO_BE_CLEANED_TXT/7 (1).txt
# Converted 66 (1).rtf to ../docs/TO_BE_CLEANED_TXT/66 (1).txt
# Converted 216 (1).rtf to ../docs/TO_BE_CLEANED_TXT/216 (1).txt
# Converted 82 (1).rtf to ../docs/TO_BE_CLEANED_TXT/82 (1).txt
# Converted 11 (2).rtf to ../docs/TO_BE_CLEANED_TXT/11 (2).txt
# Converted 1 (21).rtf to ../docs/TO_BE_CLEANED_TXT/1 (21).txt
# Converted 160 (1).rtf to ../docs/TO_BE_CLEANED_TXT/160 (1).txt
# Converted 1 (4).rtf to ../docs/TO_BE_CLEANED_TXT/1 (4).txt
# Converted 16 (6).rtf to ../docs/TO_BE_CLEANED_TXT/16 (6).txt
# Converted 49 (1).rtf to ../docs/TO_BE_CLEANED_TXT/49 (1).txt
# Converted 69.rtf to ../docs/TO_BE_CLEANED_TXT/69.txt
# Converted 197.rtf to ../docs/TO_BE_CLEANED_TXT/197.txt
# Converted 1403.rtf to ../docs/TO_BE_CLEANED_TXT/1403.txt
# Converted 59 (1).rtf to ../docs/TO_BE_CLEANED_TXT/59 (1).txt
# Converted 1371.rtf to ../docs/TO_BE_CLEANED_TXT/1371.txt
# Converted 55.rtf to ../docs/TO_BE_CLEANED_TXT/55.txt
# Converted 7.rtf to ../docs/TO_BE_CLEANED_TXT/7.txt
# Converted 41.rtf to ../docs/TO_BE_CLEANED_TXT/41.txt
# Converted 632.rtf to ../docs/TO_BE_CLEANED_TXT/632.txt
# Converted 154.rtf to ../docs/TO_BE_CLEANED_TXT/154.txt
# Converted 626.rtf to ../docs/TO_BE_CLEANED_TXT/626.txt
# Converted 5 (6).rtf to ../docs/TO_BE_CLEANED_TXT/5 (6).txt
# Converted 168.rtf to ../docs/TO_BE_CLEANED_TXT/168.txt
# Converted 82.rtf to ../docs/TO_BE_CLEANED_TXT/82.txt
# Converted 1167.rtf to ../docs/TO_BE_CLEANED_TXT/1167.txt
# Converted 12 (4).rtf to ../docs/TO_BE_CLEANED_TXT/12 (4).txt
# Converted 73 (2).rtf to ../docs/TO_BE_CLEANED_TXT/73 (2).txt
# Converted 2 (2).rtf to ../docs/TO_BE_CLEANED_TXT/2 (2).txt
# Converted 63 (2).rtf to ../docs/TO_BE_CLEANED_TXT/63 (2).txt
# Converted 13391.rtf to ../docs/TO_BE_CLEANED_TXT/13391.txt
# Converted 13395.rtf to ../docs/TO_BE_CLEANED_TXT/13395.txt
# Converted 346.rtf to ../docs/TO_BE_CLEANED_TXT/346.txt
# Converted 13381.rtf to ../docs/TO_BE_CLEANED_TXT/13381.txt
# Converted 385.rtf to ../docs/TO_BE_CLEANED_TXT/385.txt
# Converted 12 (5).rtf to ../docs/TO_BE_CLEANED_TXT/12 (5).txt
# Converted 2 (3).rtf to ../docs/TO_BE_CLEANED_TXT/2 (3).txt
# Converted 73 (3).rtf to ../docs/TO_BE_CLEANED_TXT/73 (3).txt
# Converted 340 (1).rtf to ../docs/TO_BE_CLEANED_TXT/340 (1).txt
# Converted 63 (3).rtf to ../docs/TO_BE_CLEANED_TXT/63 (3).txt
# Converted 150.rtf to ../docs/TO_BE_CLEANED_TXT/150.txt
# Converted 636.rtf to ../docs/TO_BE_CLEANED_TXT/636.txt
# Converted 15 (1).rtf to ../docs/TO_BE_CLEANED_TXT/15 (1).txt
# Converted 5 (7).rtf to ../docs/TO_BE_CLEANED_TXT/5 (7).txt
# Converted 86.rtf to ../docs/TO_BE_CLEANED_TXT/86.txt
# Converted 291 (1).rtf to ../docs/TO_BE_CLEANED_TXT/291 (1).txt
# Converted 92.rtf to ../docs/TO_BE_CLEANED_TXT/92.txt
# Converted 79.rtf to ../docs/TO_BE_CLEANED_TXT/79.txt
# Converted 1407.rtf to ../docs/TO_BE_CLEANED_TXT/1407.txt
# Converted 193.rtf to ../docs/TO_BE_CLEANED_TXT/193.txt
# Converted 45.rtf to ../docs/TO_BE_CLEANED_TXT/45.txt
# Converted 3.rtf to ../docs/TO_BE_CLEANED_TXT/3.txt
# Converted 51.rtf to ../docs/TO_BE_CLEANED_TXT/51.txt
# Converted 795.rtf to ../docs/TO_BE_CLEANED_TXT/795.txt
# Converted 67 (1).rtf to ../docs/TO_BE_CLEANED_TXT/67 (1).txt
# Converted 6 (1).rtf to ../docs/TO_BE_CLEANED_TXT/6 (1).txt
# Converted 77 (1).rtf to ../docs/TO_BE_CLEANED_TXT/77 (1).txt
# Converted 11 (3).rtf to ../docs/TO_BE_CLEANED_TXT/11 (3).txt
# Converted 232.rtf to ../docs/TO_BE_CLEANED_TXT/232.txt
# Converted 1 (20).rtf to ../docs/TO_BE_CLEANED_TXT/1 (20).txt
# Converted 1 (5).rtf to ../docs/TO_BE_CLEANED_TXT/1 (5).txt
# Converted 1943.rtf to ../docs/TO_BE_CLEANED_TXT/1943.txt
# Converted 227.rtf to ../docs/TO_BE_CLEANED_TXT/227.txt
# Converted 1228.rtf to ../docs/TO_BE_CLEANED_TXT/1228.txt
# Converted 83 (1).rtf to ../docs/TO_BE_CLEANED_TXT/83 (1).txt
# Converted 217 (1).rtf to ../docs/TO_BE_CLEANED_TXT/217 (1).txt
# Converted 10 (2).rtf to ../docs/TO_BE_CLEANED_TXT/10 (2).txt
# Converted 2.rtf to ../docs/TO_BE_CLEANED_TXT/2.txt
# Converted 2133.rtf to ../docs/TO_BE_CLEANED_TXT/2133.txt
# Converted 62 (2).rtf to ../docs/TO_BE_CLEANED_TXT/62 (2).txt
# Converted 810.rtf to ../docs/TO_BE_CLEANED_TXT/810.txt
# Converted 50.rtf to ../docs/TO_BE_CLEANED_TXT/50.txt
# Converted 44.rtf to ../docs/TO_BE_CLEANED_TXT/44.txt
# Converted 3 (2).rtf to ../docs/TO_BE_CLEANED_TXT/3 (2).txt
# Converted 72 (2).rtf to ../docs/TO_BE_CLEANED_TXT/72 (2).txt
# Converted 3 (13).rtf to ../docs/TO_BE_CLEANED_TXT/3 (13).txt
# Converted 13 (4).rtf to ../docs/TO_BE_CLEANED_TXT/13 (4).txt
# Converted 192.rtf to ../docs/TO_BE_CLEANED_TXT/192.txt
# Converted 1406.rtf to ../docs/TO_BE_CLEANED_TXT/1406.txt
# Converted 78.rtf to ../docs/TO_BE_CLEANED_TXT/78.txt
# Converted 2 (13).rtf to ../docs/TO_BE_CLEANED_TXT/2 (13).txt
# Converted 87.rtf to ../docs/TO_BE_CLEANED_TXT/87.txt
# Converted 151.rtf to ../docs/TO_BE_CLEANED_TXT/151.txt
# Converted 637.rtf to ../docs/TO_BE_CLEANED_TXT/637.txt
# Converted 1162.rtf to ../docs/TO_BE_CLEANED_TXT/1162.txt
# Converted 390.rtf to ../docs/TO_BE_CLEANED_TXT/390.txt
# Converted 58 (1).rtf to ../docs/TO_BE_CLEANED_TXT/58 (1).txt
# Converted 48 (1).rtf to ../docs/TO_BE_CLEANED_TXT/48 (1).txt
# Converted 4 (6).rtf to ../docs/TO_BE_CLEANED_TXT/4 (6).txt
# Converted 353.rtf to ../docs/TO_BE_CLEANED_TXT/353.txt
# Converted 13380.rtf to ../docs/TO_BE_CLEANED_TXT/13380.txt
# Converted 13394.rtf to ../docs/TO_BE_CLEANED_TXT/13394.txt
# Converted 13396.rtf to ../docs/TO_BE_CLEANED_TXT/13396.txt
# Converted 311 (2).rtf to ../docs/TO_BE_CLEANED_TXT/311 (2).txt
# Converted 392.rtf to ../docs/TO_BE_CLEANED_TXT/392.txt
# Converted 386.rtf to ../docs/TO_BE_CLEANED_TXT/386.txt
# Converted 13369.rtf to ../docs/TO_BE_CLEANED_TXT/13369.txt
# Converted 635.rtf to ../docs/TO_BE_CLEANED_TXT/635.txt
# Converted 153.rtf to ../docs/TO_BE_CLEANED_TXT/153.txt
# Converted 18 (3).rtf to ../docs/TO_BE_CLEANED_TXT/18 (3).txt
# Converted 91.rtf to ../docs/TO_BE_CLEANED_TXT/91.txt
# Converted 85.rtf to ../docs/TO_BE_CLEANED_TXT/85.txt
# Converted 190.rtf to ../docs/TO_BE_CLEANED_TXT/190.txt
# Converted 1410.rtf to ../docs/TO_BE_CLEANED_TXT/1410.txt
# Converted 54 (2).rtf to ../docs/TO_BE_CLEANED_TXT/54 (2).txt
# Converted 52.rtf to ../docs/TO_BE_CLEANED_TXT/52.txt
# Converted 46.rtf to ../docs/TO_BE_CLEANED_TXT/46.txt
# Converted 806.rtf to ../docs/TO_BE_CLEANED_TXT/806.txt
# Converted 57 (4).rtf to ../docs/TO_BE_CLEANED_TXT/57 (4).txt
# Converted 26 (2).rtf to ../docs/TO_BE_CLEANED_TXT/26 (2).txt
# Converted 36 (2).rtf to ../docs/TO_BE_CLEANED_TXT/36 (2).txt
# Converted 966.rtf to ../docs/TO_BE_CLEANED_TXT/966.txt
# Converted 225.rtf to ../docs/TO_BE_CLEANED_TXT/225.txt
# Converted 231.rtf to ../docs/TO_BE_CLEANED_TXT/231.txt
# Converted 298 (1).rtf to ../docs/TO_BE_CLEANED_TXT/298 (1).txt
# Converted 219.rtf to ../docs/TO_BE_CLEANED_TXT/219.txt
# Converted 288 (1).rtf to ../docs/TO_BE_CLEANED_TXT/288 (1).txt
# Converted 2 (25).rtf to ../docs/TO_BE_CLEANED_TXT/2 (25).txt
# Converted 1 (9).rtf to ../docs/TO_BE_CLEANED_TXT/1 (9).txt
# Converted haa1996207.rtf to ../docs/TO_BE_CLEANED_TXT/haa1996207.txt
# Converted 218.rtf to ../docs/TO_BE_CLEANED_TXT/218.txt
# Converted 27 (3).rtf to ../docs/TO_BE_CLEANED_TXT/27 (3).txt
# Converted 230.rtf to ../docs/TO_BE_CLEANED_TXT/230.txt
# Converted 224.rtf to ../docs/TO_BE_CLEANED_TXT/224.txt
# Converted 41 (1).rtf to ../docs/TO_BE_CLEANED_TXT/41 (1).txt
# Converted 51 (1).rtf to ../docs/TO_BE_CLEANED_TXT/51 (1).txt
# Converted 47.rtf to ../docs/TO_BE_CLEANED_TXT/47.txt
# Converted 234 (2).rtf to ../docs/TO_BE_CLEANED_TXT/234 (2).txt
# Converted 53.rtf to ../docs/TO_BE_CLEANED_TXT/53.txt
# Converted 1.rtf to ../docs/TO_BE_CLEANED_TXT/1.txt
# Converted 191.rtf to ../docs/TO_BE_CLEANED_TXT/191.txt
# Converted 1405.rtf to ../docs/TO_BE_CLEANED_TXT/1405.txt
# Converted 84.rtf to ../docs/TO_BE_CLEANED_TXT/84.txt
# Converted 23 (1).rtf to ../docs/TO_BE_CLEANED_TXT/23 (1).txt
# Converted 90.rtf to ../docs/TO_BE_CLEANED_TXT/90.txt
# Converted 33 (1).rtf to ../docs/TO_BE_CLEANED_TXT/33 (1).txt
# Converted 1 (16).rtf to ../docs/TO_BE_CLEANED_TXT/1 (16).txt
# Converted 620.rtf to ../docs/TO_BE_CLEANED_TXT/620.txt
# Converted 634.rtf to ../docs/TO_BE_CLEANED_TXT/634.txt
# Converted 152.rtf to ../docs/TO_BE_CLEANED_TXT/152.txt
# Converted 1149.rtf to ../docs/TO_BE_CLEANED_TXT/1149.txt
# Converted 13368.rtf to ../docs/TO_BE_CLEANED_TXT/13368.txt
# Converted 387.rtf to ../docs/TO_BE_CLEANED_TXT/387.txt
# Converted 393.rtf to ../docs/TO_BE_CLEANED_TXT/393.txt
# Converted 1161.rtf to ../docs/TO_BE_CLEANED_TXT/1161.txt
# Converted 13397.rtf to ../docs/TO_BE_CLEANED_TXT/13397.txt
# Converted 19 (2).rtf to ../docs/TO_BE_CLEANED_TXT/19 (2).txt
# Converted 75 (1).rtf to ../docs/TO_BE_CLEANED_TXT/75 (1).txt
# Converted 4 (1).rtf to ../docs/TO_BE_CLEANED_TXT/4 (1).txt
# Converted 479.rtf to ../docs/TO_BE_CLEANED_TXT/479.txt
# Converted 65 (1).rtf to ../docs/TO_BE_CLEANED_TXT/65 (1).txt
# Converted 323.rtf to ../docs/TO_BE_CLEANED_TXT/323.txt
# Converted 486.rtf to ../docs/TO_BE_CLEANED_TXT/486.txt
# Converted 647.rtf to ../docs/TO_BE_CLEANED_TXT/647.txt
# Converted 34.rtf to ../docs/TO_BE_CLEANED_TXT/34.txt
# Converted 3 (5).rtf to ../docs/TO_BE_CLEANED_TXT/3 (5).txt
# Converted 20.rtf to ../docs/TO_BE_CLEANED_TXT/20.txt
# Converted 2 (14).rtf to ../docs/TO_BE_CLEANED_TXT/2 (14).txt
# Converted 248 (1).rtf to ../docs/TO_BE_CLEANED_TXT/248 (1).txt
# Converted 13 (3).rtf to ../docs/TO_BE_CLEANED_TXT/13 (3).txt
# Converted 3 (14).rtf to ../docs/TO_BE_CLEANED_TXT/3 (14).txt
# Converted 61 (3).rtf to ../docs/TO_BE_CLEANED_TXT/61 (3).txt
# Converted 71 (3).rtf to ../docs/TO_BE_CLEANED_TXT/71 (3).txt
# Converted 10 (5).rtf to ../docs/TO_BE_CLEANED_TXT/10 (5).txt
# Converted 243.rtf to ../docs/TO_BE_CLEANED_TXT/243.txt
# Converted 257.rtf to ../docs/TO_BE_CLEANED_TXT/257.txt
# Converted 280.rtf to ../docs/TO_BE_CLEANED_TXT/280.txt
# Converted 17 (1).rtf to ../docs/TO_BE_CLEANED_TXT/17 (1).txt
# Converted 281.rtf to ../docs/TO_BE_CLEANED_TXT/281.txt
# Converted 11 (4).rtf to ../docs/TO_BE_CLEANED_TXT/11 (4).txt
# Converted 70 (2).rtf to ../docs/TO_BE_CLEANED_TXT/70 (2).txt
# Converted 1 (2).rtf to ../docs/TO_BE_CLEANED_TXT/1 (2).txt
# Converted 1 (27).rtf to ../docs/TO_BE_CLEANED_TXT/1 (27).txt
# Converted 60 (2).rtf to ../docs/TO_BE_CLEANED_TXT/60 (2).txt
# Converted 2036.rtf to ../docs/TO_BE_CLEANED_TXT/2036.txt
# Converted 6 (6).rtf to ../docs/TO_BE_CLEANED_TXT/6 (6).txt
# Converted 1311.rtf to ../docs/TO_BE_CLEANED_TXT/1311.txt
# Converted 28 (1).rtf to ../docs/TO_BE_CLEANED_TXT/28 (1).txt
# Converted 21.rtf to ../docs/TO_BE_CLEANED_TXT/21.txt
# Converted 35.rtf to ../docs/TO_BE_CLEANED_TXT/35.txt
# Converted 38 (1).rtf to ../docs/TO_BE_CLEANED_TXT/38 (1).txt
# Converted 15 (6).rtf to ../docs/TO_BE_CLEANED_TXT/15 (6).txt
# Converted 652.rtf to ../docs/TO_BE_CLEANED_TXT/652.txt
# Converted 2181.rtf to ../docs/TO_BE_CLEANED_TXT/2181.txt
# Converted 487.rtf to ../docs/TO_BE_CLEANED_TXT/487.txt
# Converted 12 (2).rtf to ../docs/TO_BE_CLEANED_TXT/12 (2).txt
# Converted 1107.rtf to ../docs/TO_BE_CLEANED_TXT/1107.txt
# Converted 296 (2).rtf to ../docs/TO_BE_CLEANED_TXT/296 (2).txt
# Converted 63 (4).rtf to ../docs/TO_BE_CLEANED_TXT/63 (4).txt
# Converted 4 (13).rtf to ../docs/TO_BE_CLEANED_TXT/4 (13).txt
# Converted 2 (4).rtf to ../docs/TO_BE_CLEANED_TXT/2 (4).txt
# Converted 215 (1).rtf to ../docs/TO_BE_CLEANED_TXT/215 (1).txt
# Converted 336.rtf to ../docs/TO_BE_CLEANED_TXT/336.txt
# Converted 478.rtf to ../docs/TO_BE_CLEANED_TXT/478.txt
# Converted 1 (31).rtf to ../docs/TO_BE_CLEANED_TXT/1 (31).txt
# Converted 81 (1).rtf to ../docs/TO_BE_CLEANED_TXT/81 (1).txt
# Converted 223 (1).rtf to ../docs/TO_BE_CLEANED_TXT/223 (1).txt
# Converted 34 (2).rtf to ../docs/TO_BE_CLEANED_TXT/34 (2).txt
# Converted 24 (2).rtf to ../docs/TO_BE_CLEANED_TXT/24 (2).txt
# Converted 1 (11).rtf to ../docs/TO_BE_CLEANED_TXT/1 (11).txt
# Converted 3 (9).rtf to ../docs/TO_BE_CLEANED_TXT/3 (9).txt
# Converted 644.rtf to ../docs/TO_BE_CLEANED_TXT/644.txt
# Converted 3 (18).rtf to ../docs/TO_BE_CLEANED_TXT/3 (18).txt
# Converted 2 (18).rtf to ../docs/TO_BE_CLEANED_TXT/2 (18).txt
# Converted 23.rtf to ../docs/TO_BE_CLEANED_TXT/23.txt
# Converted 37.rtf to ../docs/TO_BE_CLEANED_TXT/37.txt
# Converted 2020.rtf to ../docs/TO_BE_CLEANED_TXT/2020.txt
# Converted ca2013104.rtf to ../docs/TO_BE_CLEANED_TXT/ca2013104.txt
# Converted 1267.rtf to ../docs/TO_BE_CLEANED_TXT/1267.txt
# Converted 268.rtf to ../docs/TO_BE_CLEANED_TXT/268.txt
# Converted 56 (2).rtf to ../docs/TO_BE_CLEANED_TXT/56 (2).txt
# Converted 46 (2).rtf to ../docs/TO_BE_CLEANED_TXT/46 (2).txt
# Converted 240.rtf to ../docs/TO_BE_CLEANED_TXT/240.txt
# Converted 241 (1).rtf to ../docs/TO_BE_CLEANED_TXT/241 (1).txt
# Converted 282.rtf to ../docs/TO_BE_CLEANED_TXT/282.txt
# Converted 296.rtf to ../docs/TO_BE_CLEANED_TXT/296.txt
# Converted 2 (22).rtf to ../docs/TO_BE_CLEANED_TXT/2 (22).txt
# Converted 31 (1).rtf to ../docs/TO_BE_CLEANED_TXT/31 (1).txt
# Converted 21 (1).rtf to ../docs/TO_BE_CLEANED_TXT/21 (1).txt
# Converted 241.rtf to ../docs/TO_BE_CLEANED_TXT/241.txt
# Converted 269.rtf to ../docs/TO_BE_CLEANED_TXT/269.txt
# Converted 2021.rtf to ../docs/TO_BE_CLEANED_TXT/2021.txt
# Converted 2035.rtf to ../docs/TO_BE_CLEANED_TXT/2035.txt
# Converted 57 (3).rtf to ../docs/TO_BE_CLEANED_TXT/57 (3).txt
# Converted 25 (3).rtf to ../docs/TO_BE_CLEANED_TXT/25 (3).txt
# Converted 36.rtf to ../docs/TO_BE_CLEANED_TXT/36.txt
# Converted 22.rtf to ../docs/TO_BE_CLEANED_TXT/22.txt
# Converted 18 (4).rtf to ../docs/TO_BE_CLEANED_TXT/18 (4).txt
# Converted 69 (2).rtf to ../docs/TO_BE_CLEANED_TXT/69 (2).txt
# Converted 79 (2).rtf to ../docs/TO_BE_CLEANED_TXT/79 (2).txt
# Converted 8 (2).rtf to ../docs/TO_BE_CLEANED_TXT/8 (2).txt
# Converted 53 (1).rtf to ../docs/TO_BE_CLEANED_TXT/53 (1).txt
# Converted 321.rtf to ../docs/TO_BE_CLEANED_TXT/321.txt
# Converted 43 (1).rtf to ../docs/TO_BE_CLEANED_TXT/43 (1).txt
# Converted 309.rtf to ../docs/TO_BE_CLEANED_TXT/309.txt
# Converted 2 (8).rtf to ../docs/TO_BE_CLEANED_TXT/2 (8).txt
# Converted 325.rtf to ../docs/TO_BE_CLEANED_TXT/325.txt
# Converted 331.rtf to ../docs/TO_BE_CLEANED_TXT/331.txt
# Converted 2 (9).rtf to ../docs/TO_BE_CLEANED_TXT/2 (9).txt
# Converted 480.rtf to ../docs/TO_BE_CLEANED_TXT/480.txt
# Converted 69 (3).rtf to ../docs/TO_BE_CLEANED_TXT/69 (3).txt
# Converted 8 (3).rtf to ../docs/TO_BE_CLEANED_TXT/8 (3).txt
# Converted 154 (1).rtf to ../docs/TO_BE_CLEANED_TXT/154 (1).txt
# Converted 25 (2).rtf to ../docs/TO_BE_CLEANED_TXT/25 (2).txt
# Converted 26.rtf to ../docs/TO_BE_CLEANED_TXT/26.txt
# Converted 32.rtf to ../docs/TO_BE_CLEANED_TXT/32.txt
# Converted 47 (2).rtf to ../docs/TO_BE_CLEANED_TXT/47 (2).txt
# Converted 57 (2).rtf to ../docs/TO_BE_CLEANED_TXT/57 (2).txt
# Converted 240 (1).rtf to ../docs/TO_BE_CLEANED_TXT/240 (1).txt
# Converted 328 (1).rtf to ../docs/TO_BE_CLEANED_TXT/328 (1).txt
# Converted 2031.rtf to ../docs/TO_BE_CLEANED_TXT/2031.txt
# Converted 292.rtf to ../docs/TO_BE_CLEANED_TXT/292.txt
# Converted 2 (23).rtf to ../docs/TO_BE_CLEANED_TXT/2 (23).txt
# Converted 287.rtf to ../docs/TO_BE_CLEANED_TXT/287.txt
# Converted 293.rtf to ../docs/TO_BE_CLEANED_TXT/293.txt
# Converted 56 (3).rtf to ../docs/TO_BE_CLEANED_TXT/56 (3).txt
# Converted 46 (3).rtf to ../docs/TO_BE_CLEANED_TXT/46 (3).txt
# Converted 20 (1).rtf to ../docs/TO_BE_CLEANED_TXT/20 (1).txt
# Converted 2030.rtf to ../docs/TO_BE_CLEANED_TXT/2030.txt
# Converted 30 (1).rtf to ../docs/TO_BE_CLEANED_TXT/30 (1).txt
# Converted 33.rtf to ../docs/TO_BE_CLEANED_TXT/33.txt
# Converted 27.rtf to ../docs/TO_BE_CLEANED_TXT/27.txt
# Converted 1 (10).rtf to ../docs/TO_BE_CLEANED_TXT/1 (10).txt
# Converted 3 (8).rtf to ../docs/TO_BE_CLEANED_TXT/3 (8).txt
# Converted 42 (1).rtf to ../docs/TO_BE_CLEANED_TXT/42 (1).txt
# Converted 3 (19).rtf to ../docs/TO_BE_CLEANED_TXT/3 (19).txt
# Converted 52 (1).rtf to ../docs/TO_BE_CLEANED_TXT/52 (1).txt
# Converted 2 (19).rtf to ../docs/TO_BE_CLEANED_TXT/2 (19).txt
# Converted 24 (3).rtf to ../docs/TO_BE_CLEANED_TXT/24 (3).txt
# Converted 481.rtf to ../docs/TO_BE_CLEANED_TXT/481.txt
# Converted 9 (2).rtf to ../docs/TO_BE_CLEANED_TXT/9 (2).txt
# Converted 68 (2).rtf to ../docs/TO_BE_CLEANED_TXT/68 (2).txt
# Converted 318.rtf to ../docs/TO_BE_CLEANED_TXT/318.txt
# Converted 326.rtf to ../docs/TO_BE_CLEANED_TXT/326.txt
# Converted 468.rtf to ../docs/TO_BE_CLEANED_TXT/468.txt
# Converted 1 (30).rtf to ../docs/TO_BE_CLEANED_TXT/1 (30).txt
# Converted 12 (3).rtf to ../docs/TO_BE_CLEANED_TXT/12 (3).txt
# Converted 249 (1).rtf to ../docs/TO_BE_CLEANED_TXT/249 (1).txt
# Converted 4 (12).rtf to ../docs/TO_BE_CLEANED_TXT/4 (12).txt
# Converted 2 (5).rtf to ../docs/TO_BE_CLEANED_TXT/2 (5).txt
# Converted 64 (1).rtf to ../docs/TO_BE_CLEANED_TXT/64 (1).txt
# Converted 5 (1).rtf to ../docs/TO_BE_CLEANED_TXT/5 (1).txt
# Converted 74 (1).rtf to ../docs/TO_BE_CLEANED_TXT/74 (1).txt
# Converted 19.rtf to ../docs/TO_BE_CLEANED_TXT/19.txt
# Converted 31.rtf to ../docs/TO_BE_CLEANED_TXT/31.txt
# Converted 25.rtf to ../docs/TO_BE_CLEANED_TXT/25.txt
# Converted 16 (1).rtf to ../docs/TO_BE_CLEANED_TXT/16 (1).txt
# Converted 2026.rtf to ../docs/TO_BE_CLEANED_TXT/2026.txt
# Converted 6 (7).rtf to ../docs/TO_BE_CLEANED_TXT/6 (7).txt
# Converted 252.rtf to ../docs/TO_BE_CLEANED_TXT/252.txt
# Converted 11 (5).rtf to ../docs/TO_BE_CLEANED_TXT/11 (5).txt
# Converted 1 (3).rtf to ../docs/TO_BE_CLEANED_TXT/1 (3).txt
# Converted 1 (26).rtf to ../docs/TO_BE_CLEANED_TXT/1 (26).txt
# Converted 291.rtf to ../docs/TO_BE_CLEANED_TXT/291.txt
# Converted 290.rtf to ../docs/TO_BE_CLEANED_TXT/290.txt
# Converted 284.rtf to ../docs/TO_BE_CLEANED_TXT/284.txt
# Converted 61 (2).rtf to ../docs/TO_BE_CLEANED_TXT/61 (2).txt
# Converted 71 (2).rtf to ../docs/TO_BE_CLEANED_TXT/71 (2).txt
# Converted 10 (4).rtf to ../docs/TO_BE_CLEANED_TXT/10 (4).txt
# Converted 864.rtf to ../docs/TO_BE_CLEANED_TXT/864.txt
# Converted 24.rtf to ../docs/TO_BE_CLEANED_TXT/24.txt
# Converted 3 (4).rtf to ../docs/TO_BE_CLEANED_TXT/3 (4).txt
# Converted 2153.rtf to ../docs/TO_BE_CLEANED_TXT/2153.txt
# Converted 30.rtf to ../docs/TO_BE_CLEANED_TXT/30.txt
# Converted 18.rtf to ../docs/TO_BE_CLEANED_TXT/18.txt
# Converted 2 (15).rtf to ../docs/TO_BE_CLEANED_TXT/2 (15).txt
# Converted 13 (2).rtf to ../docs/TO_BE_CLEANED_TXT/13 (2).txt
# Converted 3 (15).rtf to ../docs/TO_BE_CLEANED_TXT/3 (15).txt
# Converted 80 (1).rtf to ../docs/TO_BE_CLEANED_TXT/80 (1).txt
# Converted 39 (1).rtf to ../docs/TO_BE_CLEANED_TXT/39 (1).txt
# Converted 29 (1).rtf to ../docs/TO_BE_CLEANED_TXT/29 (1).txt
# Converted 482.rtf to ../docs/TO_BE_CLEANED_TXT/482.txt
# Converted 327.rtf to ../docs/TO_BE_CLEANED_TXT/327.txt
# Converted 14 (6).rtf to ../docs/TO_BE_CLEANED_TXT/14 (6).txt
